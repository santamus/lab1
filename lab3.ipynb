# %% [markdown]
# <a href="https://colab.research.google.com/github/santamus/lab1/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('drive/MyDrive/Colab Notebooks/04cars.dat', sep=";", names=["Name","Sports","Sport Utility","Wagon","Minivan","Pickup","All-Wheel Drive","Rear-Wheel Drive", "Retail Price","Dealer Cost","Engine Size","Cylinders","Horsepower","City MPG","Highway MPG","Weight","Wheel Base","Length", "Width"])

# %%
data
# Out:
#                                               Name  Sports  ...  Length  Width
# 0    Chevrolet Aveo 4dr                                  0  ...   167.0   66.0
# 1    Chevrolet Aveo LS 4dr hatch                         0  ...   153.0   66.0
# 2    Chevrolet Cavalier 2dr                              0  ...   183.0   69.0
# 3    Chevrolet Cavalier 4dr                              0  ...   183.0   68.0
# 4    Chevrolet Cavalier LS 2dr                           0  ...   183.0   69.0
# ..                                             ...     ...  ...     ...    ...
# 423  Nissan Titan King Cab XE                            0  ...     NaN    NaN
# 424  Subaru Baja                                         0  ...     NaN    NaN
# 425  Toyota Tacoma                                       0  ...     NaN    NaN
# 426  Toyota Tundra Regular Cab V6                        0  ...     NaN    NaN
# 427  Toyota Tundra Access Cab V6 SR5                     0  ...     NaN    NaN
#
# [428 rows x 19 columns]

# %%
targetCol = []
for index, row in data.iterrows():
    target = 0
    if row["Sport Utility"] == 1:
        target = 1
    if row["Wagon"] == 1:
        target = 2
    if row["Minivan"] == 1:
        target = 3
    if row["Pickup"] == 1:
        target = 4
    if row["All-Wheel Drive"] == 1:
        target = 5
    if row["Rear-Wheel Drive"] == 1:
        target = 6
    targetCol.append(target)
df1 = pd.DataFrame(targetCol, columns=['target'])
data = data.join(other=df1)
data = data.drop(data.columns[[0,1,2,3,4,5,6,7]], axis=1)
data = data.dropna() 
data
# Out:
#      Retail Price  Dealer Cost  Engine Size  ...  Length  Width  target
# 0           11690        10965          1.6  ...   167.0   66.0       0
# 1           12585        11802          1.6  ...   153.0   66.0       0
# 2           14610        13697          2.2  ...   183.0   69.0       0
# 3           14810        13884          2.2  ...   183.0   68.0       0
# 4           16385        15357          2.2  ...   183.0   69.0       0
# ..            ...          ...          ...  ...     ...    ...     ...
# 399         28790        26120          3.4  ...   201.0   72.0       3
# 400         23845        21644          3.4  ...   187.0   72.0       3
# 401         31370        28454          3.4  ...   201.0   72.0       5
# 402         23495        21198          3.3  ...   200.0   77.0       3
# 403         28800        25690          3.3  ...   200.0   77.0       3
#
# [387 rows x 12 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(data.drop('target', axis=1))
scaled_features = scaler.transform(data.drop('target', axis=1))
scaled_data = pd.DataFrame(scaled_features, columns = data.drop('target', axis=1).columns)

# %%
#Разделение датасета на обучающие и тестовые данные
from sklearn.model_selection import train_test_split
x = scaled_data
y = data['target']
x_training_data, x_test_data, y_training_data, y_test_data = train_test_split(x, y, test_size = 0.25)
print(x_training_data)
print("-------------------------------------------------")
print(y_training_data)
print("-------------------------------------------------")
print(x_test_data)
print("-------------------------------------------------")
print(y_test_data)
# Out:
#      Retail Price  Dealer Cost  Engine Size  ...  Wheel Base    Length     Width
# 297     -0.339415    -0.355501     0.269111  ...    0.676536  0.154208  0.809612
# 327     -0.738163    -0.733115    -0.718053  ...   -0.877708 -1.358551  0.215077
# 149     -0.151589    -0.150780    -0.619337  ...   -0.029938 -0.677809 -0.676725
# 173      0.064156     0.062498     1.453707  ...    1.100421  2.045155  1.998682
# 189      0.470011     0.441007    -0.125755  ...   -0.312528 -0.375258 -0.379458
# ..            ...          ...          ...  ...         ...       ...       ...
# 373     -0.319871    -0.332400     0.762693  ...    1.948191  1.213138  1.701415
# 151      0.191065     0.192938    -0.125755  ...   -0.029938 -0.677809 -0.676725
# 90      -0.618107    -0.604242    -1.211635  ...   -1.160298 -0.980361 -0.973993
# 235      2.607669     2.571666     1.058842  ...    0.252652  0.456759  1.998682
# 350      0.885258     0.935972     0.071678  ...    0.676536  0.381121 -0.082190
#
# [290 rows x 11 columns]
# -------------------------------------------------
# 313    1
# 343    5
# 156    5
# 181    6
# 198    0
#       ..
# 390    3
# 158    6
# 96     0
# 246    0
# 366    6
# Name: target, Length: 290, dtype: int64
# -------------------------------------------------
#      Retail Price  Dealer Cost  Engine Size  ...  Wheel Base    Length     Width
# 264     -0.413175    -0.390683    -0.125755  ...   -0.877708 -0.602172 -0.676725
# 99      -0.417845    -0.420049     0.663976  ...    0.535242  1.137500  0.512345
# 18      -0.905734    -0.908022    -1.112919  ...   -0.595118 -0.526534 -0.973993
# 341     -0.558714    -0.561955     0.367827  ...    0.676536  0.229845 -0.379458
# 80      -0.674455    -0.673545    -0.619337  ...   -1.160298 -0.829085 -0.676725
# ..            ...          ...          ...  ...         ...       ...       ...
# 181      0.304776     0.313868     0.861409  ...   -0.171233  0.002932 -0.676725
# 266     -0.186261    -0.166386    -1.112919  ...   -0.595118 -0.450896 -0.379458
# 119     -0.246771    -0.224054     0.071678  ...   -0.029938 -0.526534 -0.973993
# 340     -0.019604    -0.018495    -0.619337  ...   -0.029938 -0.677809 -0.676725
# 270      2.585587     2.336126     0.466543  ...   -2.008068 -0.753447  0.215077
#
# [97 rows x 11 columns]
# -------------------------------------------------
# 278    0
# 105    0
# 18     0
# 357    2
# 86     5
#       ..
# 190    0
# 280    0
# 126    6
# 356    5
# 285    5
# Name: target, Length: 97, dtype: int64

# %%
#Выбор оптимального значения для K с помощью метода «Локтя»
from sklearn.neighbors import KNeighborsClassifier
error_rates = []
for i in np.arange(1, 101):
    new_model = KNeighborsClassifier(n_neighbors = i)
    new_model.fit(x_training_data, y_training_data)
    new_predictions = new_model.predict(x_test_data)
    error_rates.append(np.mean(new_predictions != y_test_data))
val, idx = min((val, idx) for (idx, val) in enumerate(error_rates))
plt.plot(error_rates)
print("K = ",idx)
print("Error = ",error_rates[idx])
# Out:
# K =  2
# Error =  0.24742268041237114

# %%
#Обучение модели K-ближайших соседей
model = KNeighborsClassifier(n_neighbors = idx)
model.fit(x_training_data, y_training_data)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='uniform')

# %%
#Делаем предсказания с помощью алгоритма K-ближайших соседей
predictions = model.predict(x_test_data)

# %%
#Оценка точности нашей модели
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
print(classification_report(y_test_data, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86        45
#            1       0.25      0.50      0.33         4
#            2       0.00      0.00      0.00         2
#            3       0.50      0.50      0.50         4
#            5       0.55      0.50      0.52        22
#            6       0.81      0.65      0.72        20
#
#     accuracy                           0.70        97
#    macro avg       0.49      0.51      0.49        97
# weighted avg       0.71      0.70      0.70        97

# %%
#Генерируем матрицу ошибок
error_matrix = confusion_matrix(y_test_data, predictions)
print(error_matrix)
print()
print("Percentage of errors = " + str(round(1-error_matrix[1,1]/np.sum(error_matrix,axis=1).tolist()[1], 3)))
# Out:
# [[40  0  1  0  4  0]
#  [ 1  2  0  0  1  0]
#  [ 2  0  0  0  0  0]
#  [ 0  2  0  2  0  0]
#  [ 2  4  0  2 11  3]
#  [ 3  0  0  0  4 13]]
#
# Percentage of errors = 0.5
